# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %%
print('Numpy Version',np.__version__)
print('Pandas Version',pd.__version__)
print('Seaborn Version',sns.__version__)
print('Matplotlib Version',matplotlib.__version__)
# Out:
# Numpy Version 1.20.1
# Pandas Version 1.2.4
# Seaborn Version 0.11.1
# Matplotlib Version 3.3.4

# %% [markdown]
# ### Read the Data¶

# %%
customer= pd.read_excel('Customer_Churn_Data.xlsx',sheet_name="Data for DSBA")
customer.head()
# Out:
#    AccountID  Churn Tenure  City_Tier  CC_Contacted_LY      Payment  Gender  \
# 0      20000      1      4        3.0              6.0   Debit Card  Female
# 1      20001      1      0        1.0              8.0          UPI    Male
# 2      20002      1      0        1.0             30.0   Debit Card    Male
# 3      20003      1      0        3.0             15.0   Debit Card    Male
# 4      20004      1      0        1.0             12.0  Credit Card    Male
#
#    Service_Score Account_user_count account_segment  CC_Agent_Score  \
# 0            3.0                  3           Super             2.0
# 1            3.0                  4    Regular Plus             3.0
# 2            2.0                  4    Regular Plus             3.0
# 3            2.0                  4           Super             5.0
# 4            2.0                  3    Regular Plus             5.0
#
#   Marital_Status rev_per_month  Complain_ly rev_growth_yoy  \
# ...

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11260 entries, 0 to 11259
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AccountID                11260 non-null  int64
#  1   Churn                    11260 non-null  int64
#  2   Tenure                   11158 non-null  object
#  3   City_Tier                11148 non-null  float64
#  4   CC_Contacted_LY          11158 non-null  float64
#  5   Payment                  11151 non-null  object
#  6   Gender                   11152 non-null  object
#  7   Service_Score            11162 non-null  float64
#  8   Account_user_count       11148 non-null  object
#  9   account_segment          11163 non-null  object
#  10  CC_Agent_Score           11144 non-null  float64
#  11  Marital_Status           11048 non-null  object
#  12  rev_per_month            11158 non-null  object
#  13  Complain_ly              10903 non-null  float64
# ...

# %%
customer.shape
# Out:
# (11260, 19)

# %%
### Examine missing values
customer_na = customer.isna().sum()
customer_na[customer_na.values > 0].sort_values(ascending=False)
# Out:
# cashback                471
# Complain_ly             357
# Day_Since_CC_connect    357
# Login_device            221
# Marital_Status          212
# CC_Agent_Score          116
# City_Tier               112
# Account_user_count      112
# Payment                 109
# Gender                  108
# Tenure                  102
# CC_Contacted_LY         102
# rev_per_month           102
# Service_Score            98
# account_segment          97
# dtype: int64

# %%
### Examine missing values
customer_na = customer.isna().sum()
customer_na.sort_values(ascending=False) /customer.shape[0]
# Out:
# cashback                   0.041829
# Day_Since_CC_connect       0.031705
# Complain_ly                0.031705
# Login_device               0.019627
# Marital_Status             0.018828
# CC_Agent_Score             0.010302
# City_Tier                  0.009947
# Account_user_count         0.009947
# Payment                    0.009680
# Gender                     0.009591
# Tenure                     0.009059
# CC_Contacted_LY            0.009059
# rev_per_month              0.009059
# Service_Score              0.008703
# account_segment            0.008615
# coupon_used_for_payment    0.000000
# rev_growth_yoy             0.000000
# Churn                      0.000000
# AccountID                  0.000000
# dtype: float64

# %% [markdown]
# As the percentage of null values in each columns is less than or equal to 4% we will not drop any missing values

# %%
customer.describe(include='all')
# Out:
#           AccountID         Churn   Tenure     City_Tier  CC_Contacted_LY  \
# count   11260.00000  11260.000000  11158.0  11148.000000     11158.000000
# unique          NaN           NaN     38.0           NaN              NaN
# top             NaN           NaN      1.0           NaN              NaN
# freq            NaN           NaN   1351.0           NaN              NaN
# mean    25629.50000      0.168384      NaN      1.653929        17.867091
# std      3250.62635      0.374223      NaN      0.915015         8.853269
# min     20000.00000      0.000000      NaN      1.000000         4.000000
# 25%     22814.75000      0.000000      NaN      1.000000        11.000000
# 50%     25629.50000      0.000000      NaN      1.000000        16.000000
# 75%     28444.25000      0.000000      NaN      3.000000        23.000000
# max     31259.00000      1.000000      NaN      3.000000       132.000000
#
#            Payment Gender  Service_Score  Account_user_count account_segment  \
# ...

# %% [markdown]
# As we can see variables such as tenure,accounts user count, rev per month, rev growth yoy, days since cc connect, cashback and coupon used are numerical variables but they are treated as object due to some feature in those columns. Similarly features such as churn and city tier are categorical features which are treated as numbers. This should be corrected before analysis

# %%
customer.Churn.value_counts(normalize='all')
# Out:
# 0    0.831616
# 1    0.168384
# Name: Churn, dtype: float64

# %%
customer.City_Tier.value_counts()
# Out:
# 1.0    7263
# 3.0    3405
# 2.0     480
# Name: City_Tier, dtype: int64

# %%
customer=customer.astype({"Churn":object,"City_Tier":object})

# %%
customer=customer.astype({"Complain_ly":object})

# %%
num=['Tenure','Account_user_count','rev_per_month','rev_growth_yoy','coupon_used_for_payment','Day_Since_CC_connect','cashback']

# %%
for i in num:
    print(i.upper(),':',customer[i].nunique())
    print(customer[i].unique())
# Out:
# TENURE : 38
# [4 0 2 13 11 '#' 9 99 19 20 14 8 26 18 5 30 7 1 23 3 29 6 28 24 25 16 10
#  15 22 nan 27 12 21 17 50 60 31 51 61]
# ACCOUNT_USER_COUNT : 7
# [3 4 nan 5 2 '@' 1 6]
# REV_PER_MONTH : 59
# [9 7 6 8 3 2 4 10 1 5 '+' 130 nan 19 139 102 120 138 127 123 124 116 21
#  126 134 113 114 108 140 133 129 107 118 11 105 20 119 121 137 110 22 101
#  136 125 14 13 12 115 23 122 117 131 104 15 25 135 111 109 100 103]
# REV_GROWTH_YOY : 20
# [11 15 14 23 22 16 12 13 17 18 24 19 20 21 25 26 '$' 4 27 28]
# COUPON_USED_FOR_PAYMENT : 20
# [1 0 4 2 9 6 11 7 12 10 5 3 13 15 8 '#' '$' 14 '*' 16]
# DAY_SINCE_CC_CONNECT : 24
# [5 0 3 7 2 1 8 6 4 15 nan 11 10 9 13 12 17 16 14 30 '$' 46 18 31 47]
# CASHBACK : 5693
# [159.93 120.9 nan ... 227.36 226.91 191.42]

# %%
customer['Tenure']=customer['Tenure'].replace('#',np.nan)

# %%
customer['Account_user_count']=customer['Account_user_count'].replace('@',np.nan)
customer['rev_per_month']=customer['rev_per_month'].replace('+',np.nan)
customer['rev_growth_yoy']=customer['rev_growth_yoy'].replace('$',np.nan)
customer['Day_Since_CC_connect']=customer['Day_Since_CC_connect'].replace('$',np.nan)
customer['coupon_used_for_payment']=customer['coupon_used_for_payment'].replace(['#','$','*'],np.nan)
customer['cashback']=customer['cashback'].replace('$',np.nan)

# %%
pd.options.display.max_rows=None

# %%
customer.describe(include='all')
# Out:
#           AccountID    Churn        Tenure  City_Tier  CC_Contacted_LY  \
# count   11260.00000  11260.0  11042.000000    11148.0     11158.000000
# unique          NaN      2.0           NaN        3.0              NaN
# top             NaN      0.0           NaN        1.0              NaN
# freq            NaN   9364.0           NaN     7263.0              NaN
# mean    25629.50000      NaN     11.025086        NaN        17.867091
# std      3250.62635      NaN     12.879782        NaN         8.853269
# min     20000.00000      NaN      0.000000        NaN         4.000000
# 25%     22814.75000      NaN      2.000000        NaN        11.000000
# 50%     25629.50000      NaN      9.000000        NaN        16.000000
# 75%     28444.25000      NaN     16.000000        NaN        23.000000
# max     31259.00000      NaN     99.000000        NaN       132.000000
#
#            Payment Gender  Service_Score  Account_user_count account_segment  \
# ...

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11260 entries, 0 to 11259
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AccountID                11260 non-null  int64
#  1   Churn                    11260 non-null  object
#  2   Tenure                   11042 non-null  float64
#  3   City_Tier                11148 non-null  object
#  4   CC_Contacted_LY          11158 non-null  float64
#  5   Payment                  11151 non-null  object
#  6   Gender                   11152 non-null  object
#  7   Service_Score            11162 non-null  float64
#  8   Account_user_count       10816 non-null  float64
#  9   account_segment          11163 non-null  object
#  10  CC_Agent_Score           11144 non-null  float64
#  11  Marital_Status           11048 non-null  object
#  12  rev_per_month            10469 non-null  float64
#  13  Complain_ly              10903 non-null  object
# ...

# %%
num
# Out:
# ['Tenure',
#  'Account_user_count',
#  'rev_per_month',
#  'rev_growth_yoy',
#  'coupon_used_for_payment',
#  'Day_Since_CC_connect',
#  'cashback']

# %%
a=['CC_Contacted_LY','Service_Score','CC_Agent_Score']

# %%
for i in a:
    num.append(i)

# %%
num
# Out:
# ['Tenure',
#  'Account_user_count',
#  'rev_per_month',
#  'rev_growth_yoy',
#  'coupon_used_for_payment',
#  'Day_Since_CC_connect',
#  'cashback',
#  'CC_Contacted_LY',
#  'Service_Score',
#  'CC_Agent_Score']

# %%
cat_1=customer.columns.drop('AccountID')

# %%
cat_1
# Out:
# Index(['Churn', 'Tenure', 'City_Tier', 'CC_Contacted_LY', 'Payment', 'Gender',
#        'Service_Score', 'Account_user_count', 'account_segment',
#        'CC_Agent_Score', 'Marital_Status', 'rev_per_month', 'Complain_ly',
#        'rev_growth_yoy', 'coupon_used_for_payment', 'Day_Since_CC_connect',
#        'cashback', 'Login_device'],
#       dtype='object')

# %%
cat=cat_1.drop(num)

# %%
cat
# Out:
# Index(['Churn', 'City_Tier', 'Payment', 'Gender', 'account_segment',
#        'Marital_Status', 'Complain_ly', 'Login_device'],
#       dtype='object')

# %%
customer.duplicated().sum()
# Out:
# 0

# %%
pd.options.display.float_format='{:.2f}'.format

for i in num:
    print(i.upper())
    print(round((customer[i].isnull().sum()/customer.shape[0])*100,2))
# Out:
# TENURE
# 1.94
# ACCOUNT_USER_COUNT
# 3.94
# REV_PER_MONTH
# 7.02
# REV_GROWTH_YOY
# 0.03
# COUPON_USED_FOR_PAYMENT
# 0.03
# DAY_SINCE_CC_CONNECT
# 3.18
# CASHBACK
# 4.2
# CC_CONTACTED_LY
# 0.91
# SERVICE_SCORE
# 0.87
# CC_AGENT_SCORE
# 1.03

# %%
for i in cat:
    print(i.upper())
    print(round((customer[i].isnull().sum()/customer.shape[0])*100,2))
# Out:
# CHURN
# 0.0
# CITY_TIER
# 0.99
# PAYMENT
# 0.97
# GENDER
# 0.96
# ACCOUNT_SEGMENT
# 0.86
# MARITAL_STATUS
# 1.88
# COMPLAIN_LY
# 3.17
# LOGIN_DEVICE
# 1.96

# %%
customer.drop('AccountID',axis=1,inplace=True)

# %%
for i in cat:
    print(i)
    print(customer[i].value_counts())
# Out:
# Churn
# 0    9364
# 1    1896
# Name: Churn, dtype: int64
# City_Tier
# 1.00    7263
# 3.00    3405
# 2.00     480
# Name: City_Tier, dtype: int64
# Payment
# Debit Card          4587
# Credit Card         3511
# E wallet            1217
# Cash on Delivery    1014
# UPI                  822
# Name: Payment, dtype: int64
# Gender
# Male      6328
# Female    4178
# M          376
# F          270
# Name: Gender, dtype: int64
# account_segment
# Super           4062
# Regular Plus    3862
# HNI             1639
# Super Plus       771
# Regular          520
# Regular +        262
# Super +           47
# Name: account_segment, dtype: int64
# Marital_Status
# Married     5860
# Single      3520
# Divorced    1668
# Name: Marital_Status, dtype: int64
# Complain_ly
# 0.00    7792
# 1.00    3111
# Name: Complain_ly, dtype: int64
# Login_device
# Mobile      7482
# Computer    3018
# &&&&         539
# Name: Login_device, dtype: int64

# %%
customer['Gender']=customer['Gender'].replace('M','Male').replace('F','Female')
customer['account_segment']=customer['account_segment'].replace('Regular +','Regular Plus').replace('Super +','Super Plus')

# %%
customer['Login_device'].value_counts(normalize=True)
# Out:
# Mobile     0.68
# Computer   0.27
# &&&&       0.05
# Name: Login_device, dtype: float64

# %%
customer['Login_device']=customer['Login_device'].replace('&&&&',customer['Login_device'].mode()[0])

# %%
for i in cat:
    print(i)
    print(customer[i].value_counts())
# Out:
# Churn
# 0    9364
# 1    1896
# Name: Churn, dtype: int64
# City_Tier
# 1.00    7263
# 3.00    3405
# 2.00     480
# Name: City_Tier, dtype: int64
# Payment
# Debit Card          4587
# Credit Card         3511
# E wallet            1217
# Cash on Delivery    1014
# UPI                  822
# Name: Payment, dtype: int64
# Gender
# Male      6704
# Female    4448
# Name: Gender, dtype: int64
# account_segment
# Regular Plus    4124
# Super           4062
# HNI             1639
# Super Plus       818
# Regular          520
# Name: account_segment, dtype: int64
# Marital_Status
# Married     5860
# Single      3520
# Divorced    1668
# Name: Marital_Status, dtype: int64
# Complain_ly
# 0.00    7792
# 1.00    3111
# Name: Complain_ly, dtype: int64
# Login_device
# Mobile      8021
# Computer    3018
# Name: Login_device, dtype: int64

# %%
num
# Out:
# ['Tenure',
#  'Account_user_count',
#  'rev_per_month',
#  'rev_growth_yoy',
#  'coupon_used_for_payment',
#  'Day_Since_CC_connect',
#  'cashback',
#  'CC_Contacted_LY',
#  'Service_Score',
#  'CC_Agent_Score']

# %%
num.remove('Service_Score')

# %%
num.remove('CC_Agent_Score')

# %%
num
# Out:
# ['Tenure',
#  'Account_user_count',
#  'rev_per_month',
#  'rev_growth_yoy',
#  'coupon_used_for_payment',
#  'Day_Since_CC_connect',
#  'cashback',
#  'CC_Contacted_LY']

# %%
cat=['Churn', 'City_Tier', 'Payment', 'Gender', 'account_segment', 'Marital_Status', 'Complain_ly', 'Login_device','Service_Score','CC_Agent_Score']

# %%
type(cat)
# Out:
# list

# %%
for i in customer:
    if customer[i].isnull().any():
        if(i in cat):
            customer[i]=customer[i].fillna(customer[i].mode()[0])
        else:
            customer[i]=customer[i].fillna(customer[i].median())

# %%
customer.isnull().sum()
# Out:
# Churn                      0
# Tenure                     0
# City_Tier                  0
# CC_Contacted_LY            0
# Payment                    0
# Gender                     0
# Service_Score              0
# Account_user_count         0
# account_segment            0
# CC_Agent_Score             0
# Marital_Status             0
# rev_per_month              0
# Complain_ly                0
# rev_growth_yoy             0
# coupon_used_for_payment    0
# Day_Since_CC_connect       0
# cashback                   0
# Login_device               0
# dtype: int64

# %%
for i in cat:
    plt.figure(figsize=(15,8))
    ax=sns.countplot(x=customer[i],data=customer,hue='Churn')
    for rect in ax.patches:
        ax.text (rect.get_x() + rect.get_width()  / 2,rect.get_height()+ 100,rect.get_height(),horizontalalignment='center', fontsize = 13)

    plt.xticks(rotation=45)
    plt.xticks(x=customer[i],fontsize=12)
    plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
from scipy.stats import skew

# %%
def univariate_analysis(column,nbins):
    print('Description of ' + column)
    print('------------------------------------------')
    print(customer[column].describe(),end=' ')
    print()
    
    plt.figure()
    print()
    print('Distribution of ' + column)
    sns.displot(customer[column],kde=True,color='g')
    plt.show()
    print("Skewness of ",column,"is equal to ",skew(customer[column]))
    print()
          
    
    plt.figure()
    print("BoxPlot of " + column)
    print("----------------------------------------------------------------------------")
    ax = sns.boxplot(x=customer[column])
    plt.show()

# %%
for x in num:
    univariate_analysis(x,20)
# Out:
# Description of Tenure
# ------------------------------------------
# count   11260.00
# mean       10.99
# std        12.76
# min         0.00
# 25%         2.00
# 50%         9.00
# 75%        16.00
# max        99.00
# Name: Tenure, dtype: float64
#
# Distribution of Tenure
# Skewness of  Tenure is equal to  3.939761387801977
#
# BoxPlot of Tenure
# ----------------------------------------------------------------------------
# Description of Account_user_count
# ------------------------------------------
# count   11260.00
# mean        3.70
# std         1.00
# min         1.00
# 25%         3.00
# 50%         4.00
# 75%         4.00
# max         6.00
# Name: Account_user_count, dtype: float64
#
# Distribution of Account_user_count
# Skewness of  Account_user_count is equal to  -0.433952407037765
#
# BoxPlot of Account_user_count
# ----------------------------------------------------------------------------
# Description of rev_per_month
# ...

# %%
pd.DataFrame(data=[customer[num].kurtosis(),customer[num].skew()],index=['kurtosis','skewness']).T.round(2)
# Out:
#                          kurtosis  skewness
# Tenure                      23.92      3.94
# Account_user_count           0.73     -0.43
# rev_per_month               93.89      9.44
# rev_growth_yoy              -0.22      0.75
# coupon_used_for_payment      9.10      2.58
# Day_Since_CC_connect         5.57      1.32
# cashback                    84.85      8.97
# CC_Contacted_LY              8.33      1.43

# %%
customer[['Service_Score','CC_Agent_Score']].describe()
# Out:
#        Service_Score  CC_Agent_Score
# count       11260.00        11260.00
# mean            2.90            3.07
# std             0.72            1.37
# min             0.00            1.00
# 25%             2.00            2.00
# 50%             3.00            3.00
# 75%             3.00            4.00
# max             5.00            5.00

# %% [markdown]
# ## Bivariate analysis

# %%
for i in num:
    plt.figure(figsize=(10,6))
    sns.boxplot(customer['Churn'],customer[i]);
    plt.xticks(fontsize=14)
    plt.show()
# Out:
# C:\Users\harip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\harip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\harip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data=customer[num].corr(),annot=True,fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
pair=['Tenure',
 'Account_user_count',
 'rev_per_month',
 'rev_growth_yoy',
 'coupon_used_for_payment',
 'Day_Since_CC_connect',
 'cashback',
 'CC_Contacted_LY',
 'Service_Score',
 'CC_Agent_Score',
 'Churn']

# %%
sns.pairplot(customer[pair],hue='Churn')

# %%
customer_copy=customer.copy()

# %%
customer_copy_2=customer.copy()

# %%
for i in cat:
    print(customer[i].value_counts())
# Out:
# 0    9364
# 1    1896
# Name: Churn, dtype: int64
# 1.00    7375
# 3.00    3405
# 2.00     480
# Name: City_Tier, dtype: int64
# Debit Card          4696
# Credit Card         3511
# E wallet            1217
# Cash on Delivery    1014
# UPI                  822
# Name: Payment, dtype: int64
# Male      6812
# Female    4448
# Name: Gender, dtype: int64
# Regular Plus    4221
# Super           4062
# HNI             1639
# Super Plus       818
# Regular          520
# Name: account_segment, dtype: int64
# Married     6072
# Single      3520
# Divorced    1668
# Name: Marital_Status, dtype: int64
# 0.00    8149
# 1.00    3111
# Name: Complain_ly, dtype: int64
# Mobile      8242
# Computer    3018
# Name: Login_device, dtype: int64
# 3.00    5588
# 2.00    3251
# 4.00    2331
# 1.00      77
# 0.00       8
# 5.00       5
# Name: Service_Score, dtype: int64
# 3.00    3476
# 1.00    2302
# 5.00    2191
# 4.00    2127
# 2.00    1164
# Name: CC_Agent_Score, dtype: int64

# %%
cat
# Out:
# ['Churn',
#  'City_Tier',
#  'Payment',
#  'Gender',
#  'account_segment',
#  'Marital_Status',
#  'Complain_ly',
#  'Login_device',
#  'Service_Score',
#  'CC_Agent_Score']

# %%
customer=pd.get_dummies(customer,drop_first=True,columns=['Churn','City_Tier','Payment','Gender','account_segment','Marital_Status',
 'Complain_ly', 'Login_device'])

# %%
pd.options.display.max_columns = None

# %%
customer.head()
# Out:
#    Tenure  CC_Contacted_LY  Service_Score  Account_user_count  CC_Agent_Score  \
# 0    4.00             6.00           3.00                3.00            2.00
# 1    0.00             8.00           3.00                4.00            3.00
# 2    0.00            30.00           2.00                4.00            3.00
# 3    0.00            15.00           2.00                4.00            5.00
# 4    0.00            12.00           2.00                3.00            5.00
#
#    rev_per_month  rev_growth_yoy  coupon_used_for_payment  \
# 0           9.00           11.00                     1.00
# 1           7.00           15.00                     0.00
# 2           6.00           14.00                     0.00
# 3           8.00           23.00                     0.00
# 4           3.00           11.00                     1.00
#
#    Day_Since_CC_connect  cashback  Churn_1  City_Tier_2.0  City_Tier_3.0  \
# ...

# %%
def remove_outlier(col):
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
for i in num:    
    LL,UL=remove_outlier(customer[i])
    print("Proportion of outlier in ", i ,"is",round(len(customer[(customer[i]>UL)|(customer[i]<LL)])/len(customer[i]),3))
    print()
# Out:
# Proportion of outlier in  Tenure is 0.012
#
# Proportion of outlier in  Account_user_count is 0.068
#
# Proportion of outlier in  rev_per_month is 0.016
#
# Proportion of outlier in  rev_growth_yoy is 0.0
#
# Proportion of outlier in  coupon_used_for_payment is 0.123
#
# Proportion of outlier in  Day_Since_CC_connect is 0.012
#
# Proportion of outlier in  cashback is 0.088
#
# Proportion of outlier in  CC_Contacted_LY is 0.004

# %%
for column in num:
    lr,ur=remove_outlier(customer[column])
    customer[column]=np.where(customer[column]>ur,ur,customer[column])
    customer[column]=np.where(customer[column]<lr,lr,customer[column])

# %% [markdown]
# ## data Imbalance

# %%
customer['Churn_1'].value_counts(normalize=True)
# Out:
# 0   0.83
# 1   0.17
# Name: Churn_1, dtype: float64

# %%
for column in num:
    lr,ur=remove_outlier(customer_copy[column])
    customer_copy[column]=np.where(customer_copy[column]>ur,ur,customer_copy[column])
    customer_copy[column]=np.where(customer_copy[column]<lr,lr,customer_copy[column])

# %%
customer_copy.head()
# Out:
#   Churn  Tenure  City_Tier  CC_Contacted_LY      Payment  Gender  \
# 0     1    4.00       3.00             6.00   Debit Card  Female
# 1     1    0.00       1.00             8.00          UPI    Male
# 2     1    0.00       1.00            30.00   Debit Card    Male
# 3     1    0.00       3.00            15.00   Debit Card    Male
# 4     1    0.00       1.00            12.00  Credit Card    Male
#
#    Service_Score  Account_user_count account_segment  CC_Agent_Score  \
# 0           3.00                3.00           Super            2.00
# 1           3.00                4.00    Regular Plus            3.00
# 2           2.00                4.00    Regular Plus            3.00
# 3           2.00                4.00           Super            5.00
# 4           2.00                3.00    Regular Plus            5.00
#
#   Marital_Status  rev_per_month  Complain_ly  rev_growth_yoy  \
# 0         Single           9.00         1.00           11.00
# ...

# %%
customer.shape
# Out:
# (11260, 26)

# %%
customer_copy.shape
# Out:
# (11260, 18)

# %%
customer_copy_2.shape
# Out:
# (11260, 18)

# %% [markdown]
# ### Descriptive modelling

# %%
from kmodes.kprototypes import KPrototypes

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = StandardScaler()

# %%
customer_copy[num]= X.fit_transform(customer_copy[num])

# %%
catColumnsPos = [customer_copy.columns.get_loc(col) for col in list(cat)]
print('Categorical columns position  : {}'.format(catColumnsPos))
# Out:
# Categorical columns position  : [0, 2, 4, 5, 8, 10, 12, 17, 6, 9]

# %%
df=customer_copy.to_numpy()

# %%
cost = []
for x in range(2,6):
    kprototype = KPrototypes(n_jobs = -1, n_clusters = x, init = 'Huang', random_state = 0)
    clusters = kprototype.fit_predict(df, categorical = catColumnsPos)
    cost.append(kprototype.cost_)
    print('Cluster initiation: {}'.format(clusters))
# Out:
# Cluster initiation: [1 1 1 ... 1 0 1]
# Cluster initiation: [2 2 2 ... 2 1 2]
# Cluster initiation: [0 1 1 ... 0 3 0]
# Cluster initiation: [0 2 2 ... 1 3 1]

# %%
df_cost = pd.DataFrame()
df_cost['clusters'] = range(2,6)
df_cost['cost'] = cost

# %%
sns.lineplot(x='clusters', y= 'cost', data=df_cost)
# Out:
# <AxesSubplot:xlabel='clusters', ylabel='cost'>

# %%
kprototype = KPrototypes(n_jobs = -1, n_clusters = 3, init = 'Huang', random_state = 0)
clusters = kprototype.fit_predict(df, categorical = catColumnsPos)

# %%
customer_copy['clusters'] = clusters

# %%
customer_copy['clusters'].value_counts()
# Out:
# 2    5190
# 0    3116
# 1    2954
# Name: clusters, dtype: int64

# %%
customer_copy[customer_copy['clusters']==2].Churn.value_counts()
# Out:
# 0    3978
# 1    1212
# Name: Churn, dtype: int64

# %%
customer_copy[customer_copy['clusters']==1].Churn.value_counts()
# Out:
# 0    2651
# 1     303
# Name: Churn, dtype: int64

# %%
customer_copy[customer_copy['clusters']==0].Churn.value_counts()
# Out:
# 0    2735
# 1     381
# Name: Churn, dtype: int64

# %%
customer_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11260 entries, 0 to 11259
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Churn                    11260 non-null  object
#  1   Tenure                   11260 non-null  float64
#  2   City_Tier                11260 non-null  float64
#  3   CC_Contacted_LY          11260 non-null  float64
#  4   Payment                  11260 non-null  object
#  5   Gender                   11260 non-null  object
#  6   Service_Score            11260 non-null  float64
#  7   Account_user_count       11260 non-null  float64
#  8   account_segment          11260 non-null  object
#  9   CC_Agent_Score           11260 non-null  float64
#  10  Marital_Status           11260 non-null  object
#  11  rev_per_month            11260 non-null  float64
#  12  Complain_ly              11260 non-null  float64
# ...

# %%
customer_copy=customer_copy.astype({"City_Tier":object,"Complain_ly":object})

# %%
customer_copy.groupby(['clusters']).agg(['mean'])
# Out:
#          Tenure CC_Contacted_LY Service_Score Account_user_count  \
#            mean            mean          mean               mean
# clusters
# 0          0.65            0.18          2.98               0.11
# 1          0.34           -0.01          3.04               0.19
# 2         -0.59           -0.10          2.78              -0.17
#
#          CC_Agent_Score rev_per_month rev_growth_yoy coupon_used_for_payment  \
#                    mean          mean           mean                    mean
# clusters
# 0                  3.04          0.95           0.14                   -0.17
# 1                  3.07         -0.17           0.00                    0.94
# 2                  3.08         -0.47          -0.09                   -0.43
#
#          Day_Since_CC_connect cashback
#                          mean     mean
# clusters
# 0                       -0.45     0.33
# 1                        1.19     0.71
# 2                       -0.41    -0.60

# %%
customer_copy_2['clusters'] = clusters

# %%
customer_copy_2.groupby(['clusters']).agg(['mean'])
# Out:
#          Tenure City_Tier CC_Contacted_LY Service_Score Account_user_count  \
#            mean      mean            mean          mean               mean
# clusters
# 0         17.96      1.62           19.41          2.98               3.82
# 1         13.95      1.73           17.77          3.04               3.89
# 2          5.11      1.62           16.96          2.78               3.53
#
#          CC_Agent_Score rev_per_month Complain_ly rev_growth_yoy  \
#                    mean          mean        mean           mean
# clusters
# 0                  3.04         11.22        0.28          16.71
# 1                  3.07          5.18        0.26          16.21
# 2                  3.08          3.91        0.28          15.87
#
#          coupon_used_for_payment Day_Since_CC_connect cashback
#                             mean                 mean     mean
# clusters
# 0                           1.35                 2.98   217.43
# ...

# %%
sns.scatterplot(x ='Tenure',y = 'Day_Since_CC_connect', data = customer_copy_2, hue= 'clusters', palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='Tenure', ylabel='Day_Since_CC_connect'>

# %%
sns.scatterplot(x ='Churn',y = 'Day_Since_CC_connect', data = customer_copy_2, hue= 'clusters', palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='Day_Since_CC_connect'>

# %%
sns.scatterplot(x ='Tenure',y = 'Churn', data = customer_copy_2, hue= 'clusters', palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='Tenure', ylabel='Churn'>

# %%
sns.scatterplot(x ='cashback',y = 'Churn', data = customer_copy_2, hue= 'clusters', palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='cashback', ylabel='Churn'>

# %%
sns.scatterplot(x ='cashback',y = 'coupon_used_for_payment', data = customer_copy_2, hue= 'clusters', palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='cashback', ylabel='coupon_used_for_payment'>

# %%
sns.scatterplot(x ='Churn',y = 'coupon_used_for_payment', data = customer_copy_2, hue= 'clusters', palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='coupon_used_for_payment'>

# %% [markdown]
# ### Building a base model

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Scaling the dataset

# %%
customer.head()
# Out:
#    Tenure  CC_Contacted_LY  Service_Score  Account_user_count  CC_Agent_Score  \
# 0    4.00             6.00           3.00                3.00            2.00
# 1    0.00             8.00           3.00                4.00            3.00
# 2    0.00            30.00           2.00                4.00            3.00
# 3    0.00            15.00           2.00                4.00            5.00
# 4    0.00            12.00           2.00                3.00            5.00
#
#    rev_per_month  rev_growth_yoy  coupon_used_for_payment  \
# 0           9.00           11.00                     1.00
# 1           7.00           15.00                     0.00
# 2           6.00           14.00                     0.00
# 3           8.00           23.00                     0.00
# 4           3.00           11.00                     1.00
#
#    Day_Since_CC_connect  cashback  Churn_1  City_Tier_2.0  City_Tier_3.0  \
# ...

# %%
X=customer.drop('Churn_1',axis=1)
y=customer.pop('Churn_1')

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3 , random_state=1,stratify=y)

# %%
sc= StandardScaler()

# %%
X_train_sc=sc.fit_transform(X_train) 
X_test_sc=sc.transform(X_test)

# %%
X_train_sc=pd.DataFrame(X_train_sc,columns=X_train.columns,index=X_train.index)
X_test_sc=pd.DataFrame(X_test_sc,columns=X_test.columns,index=X_test.index)

# %% [markdown]
# ### building base model with logistic regression with all the features

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

# %%
Log_Re_model = LogisticRegression()
Log_Re_model.fit(X_train_sc, y_train)
# Out:
# LogisticRegression()

# %%
ytrain_predict = Log_Re_model.predict(X_train_sc)
ytest_predict = Log_Re_model.predict(X_test_sc)

# %%
Log_Re_model.score(X_train, y_train)
# Out:
# 0.8316417153006851

# %%
Log_Re_model.score(X_test, y_test)
# Out:
# 0.8315571343990527

# %%
print(classification_report(y_train, ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      6555
#            1       0.77      0.51      0.62      1327
#
#     accuracy                           0.89      7882
#    macro avg       0.84      0.74      0.78      7882
# weighted avg       0.88      0.89      0.88      7882

# %%
print(classification_report(y_test, ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      2809
#            1       0.78      0.50      0.61       569
#
#     accuracy                           0.89      3378
#    macro avg       0.85      0.74      0.78      3378
# weighted avg       0.89      0.89      0.88      3378

# %%
# Training Data Probability Prediction
pred_prob_train = Log_Re_model.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = Log_Re_model.predict_proba(X_test)

# %%
# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.775
# AUC for the Test Data: 0.751

# %% [markdown]
# ### Selecting the important features using RFECV (recursive feature elimination)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.pipeline import Pipeline

# %%
rf_classfier=RandomForestClassifier()

# %%
rfe = RFECV(estimator=rf_classfier,scoring='recall')

# %%
pipeline = Pipeline(steps=[('s',rfe),('m',Log_Re_model)])

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train_sc, y_train, scoring='recall', cv=cv, n_jobs=-1, error_score='raise')

# %%
n_scores
# Out:
# array([0.48120301, 0.56390977, 0.5530303 , 0.45454545, 0.50757576,
#        0.57894737, 0.45112782, 0.5112782 , 0.44360902, 0.41353383,
#        0.52631579, 0.5037594 , 0.50757576, 0.56818182, 0.50757576,
#        0.45864662, 0.48120301, 0.44360902, 0.42105263, 0.48120301,
#        0.47368421, 0.5112782 , 0.4469697 , 0.53030303, 0.46212121,
#        0.42105263, 0.4887218 , 0.5112782 , 0.47368421, 0.52631579])

# %%
from statistics import mean
import numpy as np

# %%
# report performance
print('recall: %.3f (%.3f)' % (mean(n_scores), np.std(n_scores)))
# Out:
# recall: 0.490 (0.044)

# %%
rfe.fit(X_train_sc,y_train)
# Out:
# RFECV(estimator=RandomForestClassifier(), scoring='recall')

# %%
rfe.n_features_
# Out:
# 17

# %%
df1 = pd.DataFrame({'Feature': X_train_sc.columns, 'Rank': rfe.ranking_})

# %%
df1[df1['Rank']==1]
# Out:
#                          Feature  Rank
# 0                         Tenure     1
# 1                CC_Contacted_LY     1
# 2                  Service_Score     1
# 3             Account_user_count     1
# 4                 CC_Agent_Score     1
# 5                  rev_per_month     1
# 6                 rev_growth_yoy     1
# 7        coupon_used_for_payment     1
# 8           Day_Since_CC_connect     1
# 9                       cashback     1
# 11                 City_Tier_3.0     1
# 12           Payment_Credit Card     1
# 16                   Gender_Male     1
# 18  account_segment_Regular Plus     1
# 22         Marital_Status_Single     1
# 23               Complain_ly_1.0     1
# 24           Login_device_Mobile     1

# %%
df2=df1[df1['Rank']==1]

# %%
important=df2['Feature'].tolist()

# %%
important
# Out:
# ['Tenure',
#  'CC_Contacted_LY',
#  'Service_Score',
#  'Account_user_count',
#  'CC_Agent_Score',
#  'rev_per_month',
#  'rev_growth_yoy',
#  'coupon_used_for_payment',
#  'Day_Since_CC_connect',
#  'cashback',
#  'City_Tier_3.0',
#  'Payment_Credit Card',
#  'Gender_Male',
#  'account_segment_Regular Plus',
#  'Marital_Status_Single',
#  'Complain_ly_1.0',
#  'Login_device_Mobile']

# %%
selected_features=customer[important]

# %%
selected_features.shape
# Out:
# (11260, 17)

# %%
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score \n of number of selected features")
plt.plot(range(1, len(rfe.grid_scores_) + 1), rfe.grid_scores_)
plt.show()

# %% [markdown]
# ### Not required

# %%
def get_models():
    models = dict()
    for i in range(2, 26):
        rfe = RFE(estimator=rf_classfier, n_features_to_select=i)
        model = LogisticRegression()
        models[str(i)] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# %%
def evaluate_model(model, X, y):
    cv = StratifiedKFold(n_splits=10, shuffle=True , random_state=1)
    scores = cross_val_score(model, X_train_sc, y_train, scoring='recall', cv=cv, n_jobs=-1, error_score='raise')
    return scores

# %%
models = get_models()

# %%
from sklearn.model_selection import StratifiedKFold

# %%
results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X, y)
    results.append(scores)
    names.append(name)
    print('>%s %.3f (%.3f)' % (name, mean(scores), np.std(scores)))
# Out:
# >2 0.000 (0.000)
# >3 0.038 (0.025)
# >4 0.038 (0.028)
# >5 0.102 (0.028)
# >6 0.159 (0.026)
# >7 0.202 (0.037)
# >8 0.385 (0.045)
# >9 0.396 (0.044)
# >10 0.390 (0.045)
# >11 0.442 (0.036)
# >12 0.457 (0.042)
# >13 0.453 (0.037)
# >14 0.466 (0.040)
# >15 0.472 (0.039)
# >16 0.473 (0.041)
# >17 0.479 (0.039)
# >18 0.478 (0.044)
# >19 0.478 (0.047)
# >20 0.494 (0.045)
# >21 0.494 (0.047)
# >22 0.497 (0.041)
# >23 0.503 (0.042)
# >24 0.501 (0.039)
# >25 0.508 (0.041)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-bf396916d463> in <module>
#       6     print('>%s %.3f (%.3f)' % (name, mean(scores), np.std(scores)))
#       7 # plot model performance for comparison
# ----> 8 pyplot.boxplot(results, labels=names, showmeans=True)
#       9 pyplot.show()
#
# NameError: name 'pyplot' is not defined

# %%
plt.figure(figsize=(12,8))
plt.boxplot(results, labels=names, showmeans=True)
plt.show()

# %% [markdown]
# ### Creating train and test data with important features

# %%
X_train=X_train_sc[important]

# %%
X_test=X_test_sc[important]

# %% [markdown]
# ### Applying GridSearchCV for Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid={'penalty':['l2','none','l1'],
      'solver':['sag','lbfgs','liblinear'],
      'tol':[0.00001,0.000001]}

# %%
grid_search = GridSearchCV(estimator = Log_Re_model, param_grid = grid, cv = 5,scoring='recall')

# %%
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\harip\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\harip\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\harip\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\harip\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 454, in _check_solver
#     raise ValueError(
# ValueError: penalty='none' is not supported for the liblinear solver
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...

# %%
print(grid_search.best_params_,'\n')
# Out:
# {'penalty': 'none', 'solver': 'sag', 'tol': 1e-05}

# %%
best_model_LR = grid_search.best_estimator_

# %%
ytrain_predict = best_model_LR.predict(X_train)
ytest_predict = best_model_LR.predict(X_test)

# %%
plot_confusion_matrix(best_model_LR,X_train,y_train)
print(classification_report(y_train, ytrain_predict),'\n');
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93      6555
#            1       0.75      0.49      0.59      1327
#
#     accuracy                           0.89      7882
#    macro avg       0.83      0.73      0.76      7882
# weighted avg       0.88      0.89      0.88      7882

# %%
plot_confusion_matrix(best_model_LR,X_test,y_test)
print(classification_report(y_test, ytest_predict),'\n');
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94      2809
#            1       0.77      0.48      0.59       569
#
#     accuracy                           0.89      3378
#    macro avg       0.84      0.72      0.76      3378
# weighted avg       0.88      0.89      0.88      3378

# %%
# Training Data Probability Prediction
pred_prob_train = best_model_LR.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = best_model_LR.predict_proba(X_test)

# %%
# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.878
# AUC for the Test Data: 0.853

# %% [markdown]
# ### Finding optimum threshold

# %%
# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')
# Out:
# AUC for the Training Data: 0.878

# %%
# roc curve for logistic regression model with optimal threshold
from numpy import argmax

# %%
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
print('Best Threshold=%f' % (best_thresh))
# Out:
# Best Threshold=0.196445

# %% [markdown]
# ### Fitting the optimum threshold on the dataset¶

# %%
y_class_pred_train=[]
for i in range(0,len(pred_prob_train)):
    if np.array((pred_prob_train)[:,1])[i]>best_thresh:
        a=1
    else:
        a=0
    y_class_pred_train.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_train,y_class_pred_train)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
print(metrics.classification_report(y_train,y_class_pred_train,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.954     0.825     0.885      6555
#            1      0.482     0.805     0.603      1327
#
#     accuracy                          0.821      7882
#    macro avg      0.718     0.815     0.744      7882
# weighted avg      0.875     0.821     0.837      7882

# %%
y_class_pred_test=[]
for i in range(0,len(pred_prob_test)):
    if np.array((pred_prob_test)[:,1])[i]>best_thresh:
        a=1
    else:
        a=0
    y_class_pred_test.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_test,y_class_pred_test)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
print(metrics.classification_report(y_test,y_class_pred_test,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.943     0.812     0.873      2809
#            1      0.449     0.756     0.564       569
#
#     accuracy                          0.803      3378
#    macro avg      0.696     0.784     0.718      3378
# weighted avg      0.859     0.803     0.821      3378

# %%
pip install shap
# Out:
# ...
#
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
# ...

# %%
import shap

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
explainer=shap.LinearExplainer(best_model_LR,X_train)

# %%
shap_values = explainer.shap_values(X_train)

# %%
shap.summary_plot(shap_values, features=X_train, feature_names=X_train.columns)

# %%
shap.summary_plot(shap_values, features=X_train, feature_names=X_train.columns,plot_type="bar")

# %% [markdown]
# ### Naive Bayes model¶

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
NB_model=GaussianNB()
NB_model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_train_predict = NB_model.predict(X_train)
model_score = NB_model.score(X_train,y_train)
print(model_score)
print(metrics.confusion_matrix(y_train, y_train_predict))
print(metrics.classification_report(y_train, y_train_predict))
# Out:
# 0.8594265414869322
# [[5967  588]
#  [ 520  807]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      6555
#            1       0.58      0.61      0.59      1327
#
#     accuracy                           0.86      7882
#    macro avg       0.75      0.76      0.75      7882
# weighted avg       0.86      0.86      0.86      7882

# %%
y_test_predict = NB_model.predict(X_test)
model_score = NB_model.score(X_test, y_test)
print(model_score)
print(metrics.confusion_matrix(y_test, y_test_predict))
print(metrics.classification_report(y_test, y_test_predict))
# Out:
# 0.85198342214328
# [[2539  270]
#  [ 230  339]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      2809
#            1       0.56      0.60      0.58       569
#
#     accuracy                           0.85      3378
#    macro avg       0.74      0.75      0.74      3378
# weighted avg       0.86      0.85      0.85      3378

# %%
plot_confusion_matrix(NB_model,X_train,y_train)

# %%
plot_confusion_matrix(NB_model,X_test,y_test)

# %%
# Training Data Probability Prediction
pred_prob_train = NB_model.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = NB_model.predict_proba(X_test)

# %%
# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.835
# AUC for the Test Data: 0.810

# %% [markdown]
# ### Apply grid search CV for random forest

# %%
RF_model_CV=RandomForestClassifier(random_state=1)
RF_model_CV.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
param_grid = {
    'max_depth': [3, 5,7],
    'max_features': ['auto', 'sqrt', 'log2'],
    'min_samples_leaf': [50, 100],
    'min_samples_split': [150, 300],
    'n_estimators': [101,301, 501]
}


grid_search = GridSearchCV(estimator = RF_model_CV, param_grid = param_grid, cv = 5,scoring='recall')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=1),
#              param_grid={'max_depth': [3, 5, 7],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [50, 100],
#                          'min_samples_split': [150, 300],
#                          'n_estimators': [101, 301, 501]},
#              scoring='recall')

# %%
grid_search.best_params_
# Out:
# {'max_depth': 7,
#  'max_features': 'auto',
#  'min_samples_leaf': 50,
#  'min_samples_split': 150,
#  'n_estimators': 501}

# %%
best_grid_RF = grid_search.best_estimator_

# %%
ytrain_predict_RF = best_grid_RF.predict(X_train)
ytest_predict_RF = best_grid_RF.predict(X_test)

# %%
plot_confusion_matrix(best_grid_RF,X_train,y_train)
print(classification_report(y_train, ytrain_predict_RF),'\n');
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      6555
#            1       0.82      0.46      0.59      1327
#
#     accuracy                           0.89      7882
#    macro avg       0.86      0.72      0.76      7882
# weighted avg       0.89      0.89      0.88      7882

# %%
plot_confusion_matrix(best_grid_RF,X_test,y_test)
print(classification_report(y_test, ytest_predict_RF),'\n');
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      2809
#            1       0.86      0.45      0.59       569
#
#     accuracy                           0.89      3378
#    macro avg       0.88      0.72      0.76      3378
# weighted avg       0.89      0.89      0.88      3378

# %%
# Training Data Probability Prediction
pred_prob_train = best_grid_RF.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = best_grid_RF.predict_proba(X_test)

# %%
# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.924
# AUC for the Test Data: 0.904

# %% [markdown]
# ### Adaboost¶

# %%
from sklearn.ensemble import AdaBoostClassifier


ADB_model = AdaBoostClassifier(n_estimators=200,random_state=1,learning_rate=0.5)
ADB_model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.5, n_estimators=200, random_state=1)

# %%
y_train_predict = ADB_model.predict(X_train)
model_score = ADB_model.score(X_train, y_train)
print(model_score)
print(metrics.classification_report(y_train, y_train_predict))
# Out:
# 0.9005328596802842
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      6555
#            1       0.77      0.58      0.66      1327
#
#     accuracy                           0.90      7882
#    macro avg       0.85      0.77      0.80      7882
# weighted avg       0.89      0.90      0.89      7882

# %%
plot_confusion_matrix(ADB_model,X_train,y_train)

# %%
y_test_predict = ADB_model.predict(X_test)
model_score = ADB_model.score(X_test, y_test)
print(model_score)
print(metrics.classification_report(y_test, y_test_predict))
# Out:
# 0.9002368265245707
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      2809
#            1       0.77      0.58      0.66       569
#
#     accuracy                           0.90      3378
#    macro avg       0.85      0.77      0.80      3378
# weighted avg       0.89      0.90      0.89      3378

# %%
plot_confusion_matrix(ADB_model,X_test,y_test)

# %%
# Training Data Probability Prediction
pred_prob_train = ADB_model.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = ADB_model.predict_proba(X_test)

# %%
# AUC and ROC for the training data

# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.919
# AUC for the Test Data: 0.904

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(random_state=1)
gbcl = gbcl.fit(X_train, y_train)

# %%
y_train_predict = gbcl.predict(X_train)
model_score = gbcl.score(X_train, y_train)
print(model_score)
# Out:
# 0.9210860187769602

# %%
plot_confusion_matrix(gbcl,X_train,y_train)

# %%
print(metrics.classification_report(y_train, y_train_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      6555
#            1       0.84      0.65      0.74      1327
#
#     accuracy                           0.92      7882
#    macro avg       0.89      0.81      0.84      7882
# weighted avg       0.92      0.92      0.92      7882

# %%
y_test_predict = gbcl.predict(X_test)
model_score = gbcl.score(X_test, y_test)
print(model_score)
print(metrics.classification_report(y_test, y_test_predict))
# Out:
# 0.9120781527531083
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      2809
#            1       0.82      0.61      0.70       569
#
#     accuracy                           0.91      3378
#    macro avg       0.87      0.79      0.82      3378
# weighted avg       0.91      0.91      0.91      3378

# %%
plot_confusion_matrix(gbcl,X_test,y_test)

# %%
# Training Data Probability Prediction
pred_prob_train = gbcl.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = gbcl.predict_proba(X_test)

# %%
# AUC and ROC for the training data

# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.947
# AUC for the Test Data: 0.924

# %%
# AUC and ROC for the training data

# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')
# Out:
# AUC for the Training Data: 0.947

# %% [markdown]
# ### Fine tunning probability for gradient boosting

# %% [markdown]
# ### Finding optimum threshold

# %%
# roc curve for logistic regression model with optimal threshold
from numpy import argmax

# %%
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
print('Best Threshold=%f' % (best_thresh))
# Out:
# Best Threshold=0.207839

# %% [markdown]
# ### Fitting the optimum threshold on the dataset¶

# %%
y_class_pred_train=[]
for i in range(0,len(pred_prob_train)):
    if np.array((pred_prob_train)[:,1])[i]>best_thresh:
        a=1
    else:
        a=0
    y_class_pred_train.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_train,y_class_pred_train)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
print(metrics.classification_report(y_train,y_class_pred_train,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.971     0.904     0.936      6555
#            1      0.646     0.865     0.740      1327
#
#     accuracy                          0.898      7882
#    macro avg      0.809     0.885     0.838      7882
# weighted avg      0.916     0.898     0.903      7882

# %%
y_class_pred_test=[]
for i in range(0,len(pred_prob_test)):
    if np.array((pred_prob_test)[:,1])[i]>best_thresh:
        a=1
    else:
        a=0
    y_class_pred_test.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_test,y_class_pred_test)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
print(metrics.classification_report(y_test,y_class_pred_test,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.960     0.898     0.928      2809
#            1      0.618     0.815     0.703       569
#
#     accuracy                          0.884      3378
#    macro avg      0.789     0.857     0.815      3378
# weighted avg      0.902     0.884     0.890      3378

# %% [markdown]
# ### INterpreatation

# %%
explainer=shap.TreeExplainer(gbcl,X_train)

# %%
shap_values = explainer.shap_values(X_train)
# Out:
#  95%|=================== | 7478/7882 [00:13<00:00]

# %%
shap.summary_plot(shap_values, features=X_train, feature_names=X_train.columns)

# %%
shap.summary_plot(shap_values, features=X_train, feature_names=X_train.columns,plot_type="bar")

# %% [markdown]
# ### Bagging with optimised random forest

# %%
from sklearn.ensemble import BaggingClassifier
Bagging_model=BaggingClassifier(base_estimator=best_grid_RF,random_state=1)
Bagging_model.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=RandomForestClassifier(max_depth=7,
#                                                         min_samples_leaf=50,
#                                                         min_samples_split=150,
#                                                         n_estimators=501,
#                                                         random_state=1),
#                   random_state=1)

# %%
y_train_predict = Bagging_model.predict(X_train)
model_score =Bagging_model.score(X_train, y_train)
print(model_score)
print(metrics.classification_report(y_train, y_train_predict))
# Out:
# 0.8812484141080944
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      6555
#            1       0.82      0.38      0.52      1327
#
#     accuracy                           0.88      7882
#    macro avg       0.85      0.68      0.73      7882
# weighted avg       0.88      0.88      0.86      7882

# %%
plot_confusion_matrix(Bagging_model,X_train, y_train)

# %%
plot_confusion_matrix(Bagging_model,X_test,y_test)

# %%
y_test_predict = Bagging_model.predict(X_test)
model_score = Bagging_model.score(X_test, y_test)
print(model_score)
# Out:
# 0.8845470692717584

# %%
print(metrics.classification_report(y_test, y_test_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.93      2809
#            1       0.87      0.37      0.52       569
#
#     accuracy                           0.88      3378
#    macro avg       0.88      0.68      0.73      3378
# weighted avg       0.88      0.88      0.86      3378

# %%
# Training Data Probability Prediction
pred_prob_train = Bagging_model.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = Bagging_model.predict_proba(X_test)

# %%
# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.912
# AUC for the Test Data: 0.895

# %% [markdown]
# ### Fine tunning probability for gradient boosting

# %% [markdown]
# ### Finding optimum threshold

# %%
# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')
# Out:
# AUC for the Training Data: 0.878

# %%
# roc curve for logistic regression model with optimal threshold
from numpy import argmax

# %%
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
print('Best Threshold=%f' % (best_thresh))
# Out:
# Best Threshold=0.196445

# %% [markdown]
# ### Fitting the optimum threshold on the dataset¶

# %%
y_class_pred_train=[]
for i in range(0,len(pred_prob_train)):
    if np.array((pred_prob_train)[:,1])[i]>best_thresh:
        a=1
    else:
        a=0
    y_class_pred_train.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_train,y_class_pred_train)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
print(metrics.classification_report(y_train,y_class_pred_train,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.954     0.825     0.885      6555
#            1      0.482     0.805     0.603      1327
#
#     accuracy                          0.821      7882
#    macro avg      0.718     0.815     0.744      7882
# weighted avg      0.875     0.821     0.837      7882

# %%
y_class_pred_test=[]
for i in range(0,len(pred_prob_test)):
    if np.array((pred_prob_test)[:,1])[i]>best_thresh:
        a=1
    else:
        a=0
    y_class_pred_test.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_test,y_class_pred_test)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
print(metrics.classification_report(y_test,y_class_pred_test,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.943     0.812     0.873      2809
#            1      0.449     0.756     0.564       569
#
#     accuracy                          0.803      3378
#    macro avg      0.696     0.784     0.718      3378
# weighted avg      0.859     0.803     0.821      3378
